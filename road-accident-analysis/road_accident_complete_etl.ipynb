# %% [markdown]
# # 🚗 Road Accident Data Analysis Portfolio
# ## Complete ETL Pipeline: Data Cleaning → Tableau Visualization → SQL Verification
#
# **Project Overview:**
# - **Goal**: Analyze UK road accident patterns using visualization-first approach
# - **Method**: Clean raw data → Create Tableau dashboard → Verify with SQL
# - **Dataset**: UK Road Accident Data (2019-2022)
# - **Tech Stack**: Python (Pandas), SQL (MySQL), Tableau
#
# **Complete Workflow:**
# 1. **Data Loading & Exploration** - Load raw CSV data
# 2. **Data Cleaning & Preprocessing** - Handle datetime formatting issues
# 3. **ETL to Database** - Transfer cleaned data to MySQL
# 4. **Cross-Platform Analysis** - Tableau visualization + SQL verification
#
# ---

# %% [markdown]
# ## 📊 Step 1: Data Loading and Initial Exploration
# **데이터 로드 및 초기 탐색**

# %%
# Import necessary libraries
# 필요한 라이브러리 가져오기
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.types import DateTime

# %%
# Load the raw road accident dataset
# 원본 도로교통사고 데이터셋 로드
road_accident = pd.read_csv('data/road_accident_raw.csv')

# Display basic information about the dataset
# 데이터셋 기본 정보 확인
road_accident.head(20)
# Out:
#    accident_index accident_date day_of_week              junction_control  \
# 0       BS0000001        1/1/21    Thursday      Give way or uncontrolled
# 1       BS0000002        5/1/21      Monday      Give way or uncontrolled
# 2       BS0000003        4/1/21      Sunday      Give way or uncontrolled
# 3       BS0000004        5/1/21      Monday           Auto traffic signal
# 4       BS0000005        6/1/21     Tuesday           Auto traffic signal
# 5       BS0000006        1/1/21    Thursday      Give way or uncontrolled
# 6       BS0000007        8/1/21    Thursday      Give way or uncontrolled
# 7       BS0000008        2/1/21      Friday           Auto traffic signal
# 8       BS0000009        7/1/21   Wednesday      Give way or uncontrolled
# 9       BS0000010       10/1/21    Saturday           Auto traffic signal
# 10      BS0000011        7/1/21   Wednesday           Auto traffic signal
# 11      BS0000012    16-01-2021      Friday           Auto traffic signal
# 12      BS0000013       12/1/21      Monday  Data missing or out of range
# 13      BS0000014        9/1/21      Friday      Give way or uncontrolled
# 14      BS0000015    17-01-2021    Saturday      Give way or uncontrolled
# 15      BS0000016    25-01-2021      Sunday           Auto traffic signal
# 16      BS0000017    26-01-2021      Monday      Give way or uncontrolled
# 17      BS0000018    26-01-2021      Monday  Data missing or out of range
# 18      BS0000019    19-01-2021      Monday      Give way or uncontrolled
# 19      BS0000020    27-01-2021     Tuesday  Data missing or out of range
#
#                         junction_detail accident_severity  \
# 0               T or staggered junction           Serious
# 1                            Crossroads           Serious
# 2               T or staggered junction            Slight
# 3               T or staggered junction           Serious
# 4                            Crossroads           Serious
# 5               T or staggered junction            Slight
# 6               T or staggered junction           Serious
# 7                            Crossroads            Slight
# 8               T or staggered junction            Slight
# 9                            Crossroads            Slight
# 10                           Crossroads            Slight
# 11                           Crossroads            Slight
# 12  Not at junction or within 20 metres            Slight
# 13              T or staggered junction            Slight
# 14              T or staggered junction            Slight
# 15                           Crossroads           Serious
# 16                           Crossroads            Slight
# 17  Not at junction or within 20 metres            Slight
# 18              T or staggered junction            Slight
# 19  Not at junction or within 20 metres            Slight
#
#          light_conditions         local_authority carriageway_hazards  \
# 0                Daylight  Kensington and Chelsea                 NaN
# 1                Daylight  Kensington and Chelsea                 NaN
# 2                Daylight  Kensington and Chelsea                 NaN
# 3                Daylight  Kensington and Chelsea                 NaN
# 4   Darkness - lights lit  Kensington and Chelsea                 NaN
# 5                Daylight  Kensington and Chelsea                 NaN
# 6                Daylight  Kensington and Chelsea                 NaN
# 7                Daylight  Kensington and Chelsea                 NaN
# 8                Daylight  Kensington and Chelsea                 NaN
# 9                Daylight  Kensington and Chelsea                 NaN
# 10  Darkness - lights lit  Kensington and Chelsea                 NaN
# 11  Darkness - lights lit  Kensington and Chelsea                 NaN
# 12               Daylight  Kensington and Chelsea                 NaN
# 13               Daylight  Kensington and Chelsea                 NaN
# 14               Daylight  Kensington and Chelsea                 NaN
# 15  Darkness - lights lit  Kensington and Chelsea                 NaN
# 16  Darkness - lights lit  Kensington and Chelsea                 NaN
# 17  Darkness - lights lit  Kensington and Chelsea                 NaN
# 18               Daylight  Kensington and Chelsea                 NaN
# 19  Darkness - lights lit  Kensington and Chelsea                 NaN
#
#     number_of_casualties  number_of_vehicles         police_force  \
# 0                      1                   2  Metropolitan Police
# 1                     11                   2  Metropolitan Police
# 2                      1                   2  Metropolitan Police
# 3                      1                   2  Metropolitan Police
# 4                      1                   2  Metropolitan Police
# 5                      3                   2  Metropolitan Police
# 6                      1                   2  Metropolitan Police
# 7                      1                   1  Metropolitan Police
# 8                      2                   1  Metropolitan Police
# 9                      1                   1  Metropolitan Police
# 10                     1                   2  Metropolitan Police
# 11                     1                   1  Metropolitan Police
# 12                     1                   2  Metropolitan Police
# 13                     1                   2  Metropolitan Police
# 14                     1                   2  Metropolitan Police
# 15                     1                   2  Metropolitan Police
# 16                     1                   2  Metropolitan Police
# 17                     1                   1  Metropolitan Police
# 18                     1                   2  Metropolitan Police
# 19                     1                   1  Metropolitan Police
#
#    road_surface_conditions           road_type  speed_limit   time  \
# 0                      Dry      One way street           30  15:11
# 1              Wet or damp  Single carriageway           30  10:59
# 2                      Dry  Single carriageway           30  14:19
# 3             Frost or ice  Single carriageway           30   8:10
# 4                      Dry  Single carriageway           30  17:25
# 5                      Dry  Single carriageway           30  11:48
# 6                      Dry  Single carriageway           30  13:58
# 7                      Dry    Dual carriageway           30  13:18
# 8                      Dry  Single carriageway           30  12:15
# 9              Wet or damp  Single carriageway           30   9:52
# 10                     Dry  Single carriageway           30   0:09
# 11                     Dry  Single carriageway           30  17:49
# 12             Wet or damp  Single carriageway           30  14:00
# 13             Wet or damp  Single carriageway           30   8:15
# 14                     Dry  Single carriageway           30  12:15
# 15                     Dry  Single carriageway           30  22:05
# 16                     Dry  Single carriageway           30  17:30
# 17                     Dry  Single carriageway           30  17:05
# 18             Wet or damp  Single carriageway           30  14:27
# 19                     Dry  Single carriageway           30   0:28
#
#    urban_or_rural_area     weather_conditions  \
# 0                Urban     Fine no high winds
# 1                Urban     Fine no high winds
# 2                Urban     Fine no high winds
# 3                Urban                  Other
# 4                Urban     Fine no high winds
# 5                Urban     Fine no high winds
# 6                Urban     Fine no high winds
# 7                Urban     Fine no high winds
# 8                Urban     Fine no high winds
# 9                Urban                  Other
# 10               Urban     Fine no high winds
# 11               Urban     Fine no high winds
# 12               Urban  Raining no high winds
# 13               Urban  Raining no high winds
# 14               Urban     Fine no high winds
# 15               Urban     Fine no high winds
# 16               Urban     Fine no high winds
# 17               Urban     Fine no high winds
# 18               Urban     Fine no high winds
# 19               Urban     Fine no high winds
#
#                            vehicle_type
# 0                                   Car
# 1                 Taxi/Private hire car
# 2                 Taxi/Private hire car
# 3                 Motorcycle over 500cc
# 4                                   Car
# 5                                   Car
# 6                 Motorcycle over 500cc
# 7                                   Car
# 8   Van / Goods 3.5 tonnes mgw or under
# 9                                   Car
# 10                                  Car
# 11                                  Car
# 12                                  Car
# 13                                  Car
# 14                                  Car
# 15                                  Car
# 16  Van / Goods 3.5 tonnes mgw or under
# 17                                  Car
# 18                                  Car
# 19                                  Car

# %%
road_accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307973 entries, 0 to 307972
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   accident_index           307973 non-null  object
#  1   accident_date            307973 non-null  object
#  2   day_of_week              307973 non-null  object
#  3   junction_control         307973 non-null  object
#  4   junction_detail          307973 non-null  object
#  5   accident_severity        307973 non-null  object
#  6   light_conditions         307973 non-null  object
#  7   local_authority          307973 non-null  object
#  8   carriageway_hazards      5424 non-null    object
#  9   number_of_casualties     307973 non-null  int64
#  10  number_of_vehicles       307973 non-null  int64
#  11  police_force             307973 non-null  object
#  12  road_surface_conditions  307973 non-null  object
#  13  road_type                307973 non-null  object
#  14  speed_limit              307973 non-null  int64
#  15  time                     307956 non-null  object
#  16  urban_or_rural_area      307973 non-null  object
#  17  weather_conditions       307973 non-null  object
#  18  vehicle_type             307973 non-null  object
# dtypes: int64(3), object(16)
# memory usage: 44.6+ MB

# %% [markdown]
# ## 🔍 Step 2: Data Quality Assessment
# **데이터 품질 평가**
#
# ### Identifying Data Issues
# **데이터 문제점 식별**

# %%
# Examine accident_date column for formatting issues
# accident_date 컬럼의 형식 문제 확인
print("=== Accident Date Format Analysis ===")
print("Sample accident_date values:")
print(road_accident['accident_date'].head(20))

print("\n=== Unique Date Formats Detected ===")
# Check for different date formats in the data
# 데이터에서 다른 날짜 형식 확인
sample_dates = road_accident['accident_date'].sample(10)
for date in sample_dates:
    print(f"Date format example: {date}")
# Out:
# === Accident Date Format Analysis ===
# Sample accident_date values:
# 0         1/1/21
# 1         5/1/21
# 2         4/1/21
# 3         5/1/21
# 4         6/1/21
# 5         1/1/21
# 6         8/1/21
# 7         2/1/21
# 8         7/1/21
# 9        10/1/21
# 10        7/1/21
# 11    16-01-2021
# 12       12/1/21
# 13        9/1/21
# 14    17-01-2021
# 15    25-01-2021
# 16    26-01-2021
# 17    26-01-2021
# 18    19-01-2021
# 19    27-01-2021
# Name: accident_date, dtype: object
#
# === Unique Date Formats Detected ===
# Date format example: 4/4/22
# Date format example: 10/4/22
# Date format example: 28-11-2021
# Date format example: 30-04-2022
# Date format example: 19-06-2022
# Date format example: 19-10-2022
# Date format example: 18-09-2021
# Date format example: 30-10-2021
# Date format example: 28-10-2022
# Date format example: 10/8/21

# %%
# Examine time column format
# time 컬럼 형식 확인
print("=== Time Format Analysis ===")
print("Sample time values:")
print(road_accident['time'].head(20))
print(f"\nTime column data type: {road_accident['time'].dtype}")
# Out:
# === Time Format Analysis ===
# Sample time values:
# 0     15:11
# 1     10:59
# 2     14:19
# 3      8:10
# 4     17:25
# 5     11:48
# 6     13:58
# 7     13:18
# 8     12:15
# 9      9:52
# 10     0:09
# 11    17:49
# 12    14:00
# 13     8:15
# 14    12:15
# 15    22:05
# 16    17:30
# 17    17:05
# 18    14:27
# 19     0:28
# Name: time, dtype: object
#
# Time column data type: object

# %% [markdown]
# ## 🧹 Step 3: Data Cleaning & Preprocessing
# **데이터 정제 및 전처리**
#
# ### Issue Identified:
# **발견된 문제:**
# - **Mixed date formats**: Some dates in 'DD/MM/YY', others in 'DD-MM-YYYY'
# - **Time format**: Stored as 'HH:MM' strings, need to combine with date
# - **Data type**: Need to convert to proper datetime format for analysis
#
# **혼재된 날짜 형식, 시간 형식 문제, 올바른 datetime 형식으로 변환 필요**
#
# ### Analysis Approach:
# **분석 접근법:**
# While this current analysis focuses on aggregate patterns and does not require time-series analysis, I'm combining the date and time columns to create complete datetime information. This preserves temporal detail for potential future time-series analysis (hourly patterns, rush hour effects, etc.).
#
# **이 분석에서는 집계 패턴에 초점을 맞추고 시계열 분석은 수행하지 않지만, 향후 시계열 분석(시간대별 패턴, 러시아워 효과 등)을 위해 날짜와 시간 컬럼을 결합하여 완전한 날짜시간 정보를 만들었다.**

# %%
# Step 1: Convert accident_date from string to datetime format
# 1단계: accident_date를 문자열에서 datetime 형식으로 변환

print("Converting accident_date to datetime format...")
print("accident_date 를 datetime 형식으로 변환 중...")

road_accident['accident_date'] = pd.to_datetime(
    road_accident['accident_date'],
    format='mixed',        # Handle multiple date formats
    dayfirst=True,         # UK format: day first
    errors='coerce'        
)

# Check the result 결과 확인
print("\n=== After Date Conversion ===")
print(road_accident['accident_date'].head())
print(f"Data type: {road_accident['accident_date'].dtype}")
# Out:
# Converting accident_date to datetime format...
# accident_date 를 datetime 형식으로 변환 중...
#
# === After Date Conversion ===
# 0   2021-01-01
# 1   2021-01-05
# 2   2021-01-04
# 3   2021-01-05
# 4   2021-01-06
# Name: accident_date, dtype: datetime64[ns]
# Data type: datetime64[ns]

# %%
# Step 2: Combine date and time into a single datetime column
# 2단계: 날짜와 시간을 하나의 datetime 컬럼으로 결합

print("Combining date and time columns...")
print("날짜와 시간 컬럼 결합 중...")

# Convert time strings to timedelta (duration since midnight)
# 시간 문자열을 timedelta로 변환 (자정부터의 지속시간)
road_accident['accident_time'] = pd.to_timedelta(
    road_accident['time'] + ':00'  # Add seconds to make 'HH:MM:SS'
)

# Combine date + time for complete datetime
# 완전한 datetime을 위해 날짜 + 시간 결합
road_accident['accident_date'] = (
    road_accident['accident_date'] + road_accident['accident_time']
)

# Clean up: Remove temporary columns
# 정리: 임시 컬럼 제거
road_accident = road_accident.drop(columns=['accident_time', 'time'])

print("\n=== After Date-Time Combination ===")
print(road_accident['accident_date'].head())
# Out:
# Combining date and time columns...
# 날짜와 시간 컬럼 결합 중...
#
# === After Date-Time Combination ===
# 0   2021-01-01 15:11:00
# 1   2021-01-05 10:59:00
# 2   2021-01-04 14:19:00
# 3   2021-01-05 08:10:00
# 4   2021-01-06 17:25:00
# Name: accident_date, dtype: datetime64[ns]

# %%
# Step 3: Verify data cleaning results
# 3단계: 데이터 정제 결과 검증

print("=== Data Cleaning Verification ===")
print("데이터 정제 결과 검증")

# Check for any null values after conversion
# 변환 후 null 값 확인
null_dates = road_accident['accident_date'].isnull().sum()
print(f"\nNull values in accident_date: {null_dates}")

# Show date range
# 날짜 범위 표시
print(f"Date range: {road_accident['accident_date'].min()} to {road_accident['accident_date'].max()}")

# Display final cleaned data structure
# 최종 정제된 데이터 구조 표시
print(f"\nFinal dataset shape: {road_accident.shape}")
road_accident.head()
# Out:
# === Data Cleaning Verification ===
# 데이터 정제 결과 검증
#
# Null values in accident_date: 17
# Date range: 2021-01-01 00:01:00 to 2022-12-31 23:30:00
#
# Final dataset shape: (307973, 18)
#   accident_index       accident_date day_of_week          junction_control  \
# 0      BS0000001 2021-01-01 15:11:00    Thursday  Give way or uncontrolled
# 1      BS0000002 2021-01-05 10:59:00      Monday  Give way or uncontrolled
# 2      BS0000003 2021-01-04 14:19:00      Sunday  Give way or uncontrolled
# 3      BS0000004 2021-01-05 08:10:00      Monday       Auto traffic signal
# 4      BS0000005 2021-01-06 17:25:00     Tuesday       Auto traffic signal
#
#            junction_detail accident_severity       light_conditions  \
# 0  T or staggered junction           Serious               Daylight
# 1               Crossroads           Serious               Daylight
# 2  T or staggered junction            Slight               Daylight
# 3  T or staggered junction           Serious               Daylight
# 4               Crossroads           Serious  Darkness - lights lit
#
#           local_authority carriageway_hazards  number_of_casualties  \
# 0  Kensington and Chelsea                 NaN                     1
# 1  Kensington and Chelsea                 NaN                    11
# 2  Kensington and Chelsea                 NaN                     1
# 3  Kensington and Chelsea                 NaN                     1
# 4  Kensington and Chelsea                 NaN                     1
#
#    number_of_vehicles         police_force road_surface_conditions  \
# 0                   2  Metropolitan Police                     Dry
# 1                   2  Metropolitan Police             Wet or damp
# 2                   2  Metropolitan Police                     Dry
# 3                   2  Metropolitan Police            Frost or ice
# 4                   2  Metropolitan Police                     Dry
#
#             road_type  speed_limit urban_or_rural_area  weather_conditions  \
# 0      One way street           30               Urban  Fine no high winds
# 1  Single carriageway           30               Urban  Fine no high winds
# 2  Single carriageway           30               Urban  Fine no high winds
# 3  Single carriageway           30               Urban               Other
# 4  Single carriageway           30               Urban  Fine no high winds
#
#             vehicle_type
# 0                    Car
# 1  Taxi/Private hire car
# 2  Taxi/Private hire car
# 3  Motorcycle over 500cc
# 4                    Car

# %% [markdown]
# ## 💾 Step 4: Save Cleaned Data
# **정제된 데이터 저장**

# %%
# Save the cleaned dataset
# 정제된 데이터셋 저장
file_path = 'data/road_accident_cleaned.csv'

road_accident.to_csv(
    file_path,
    index=False
)

print(f"✅ Cleaned dataset saved to: {file_path}")
# Out:
# ✅ Cleaned dataset saved to: data/road_accident_cleaned.csv

# %%
# Create a sample dataset for demonstration
# 데모용 샘플 데이터셋 생성
cleaned_sample_df = road_accident.head(1000)

sample_file = 'data/road_accident_cleaned_sample.csv'
cleaned_sample_df.to_csv(
    sample_file,
    index=False
)

print(f"✅ Sample dataset (1000 rows) saved to: {sample_file}")
# Out:
# ✅ Sample dataset (1000 rows) saved to: data/road_accident_cleaned_sample.csv

# %% [markdown]
# ## 🔄 Step 5: ETL to SQL Database
# **SQL 데이터베이스로 ETL**
#
# Now that our data is properly cleaned and formatted, we'll transfer it to MySQL for analysis.
#
# **데이터가 적절히 정제되었으므로 분석을 위해 MySQL로 전송한다.**

# %%
# Database connection setup (replace with your credentials)
# 데이터베이스 연결 설정 (개인 인증 정보로 교체)
DATABASE_URL = "mysql+pymysql://root:password@localhost:3306/portfolioproject"
engine = create_engine(DATABASE_URL)

print("데이터베이스 연결 완료 ✅")

# %%
# Transfer cleaned DataFrame to SQL database
# 정제된 DataFrame을 SQL 데이터베이스로 전송

road_accident.to_sql(
    name="road_accident",               # Table name in database
    con=engine,                         # Database connection
    if_exists="replace",                # Replace table if exists
    index=False,                        # Don't include DataFrame index
    dtype={'accident_date': DateTime()} # Ensure proper datetime format
)


print("✅ 전송 완료! 이제 workbench로 가서 확인해보자!")

# %% [markdown]
# ## 🎯 Next Steps: Tableau & SQL Analysis
# **다음 단계: Tableau 및 SQL 분석**
#
# ### Analysis Workflow:
# **분석 워크플로우:**
#
# 1. **🔍 SQL Cross-Validation**
#    - Write detailed queries to verify Tableau findings
#    - Ensure data consistency across platforms
#    - Calculate same metrics using SQL<br>
# 2. **📈 Key Analysis Areas:**
#    - **Primary KPIs**: Total casualties, accidents, severity breakdown
#    - **Vehicle Analysis**: Casualties by vehicle type
#    - **Geographic Analysis**: Urban vs Rural, high-risk locations
#    - **Environmental Factors**: Weather, road conditions impact
#
# **Continue to SQL analysis: `road_accident_eda.sql`**
# **SQL 분석 파일로 계속: `road_accident_eda.sql`**
